# %%
fp=open('nif_context_en.tql','r')

# %%
fl=fp.readline()

# %%
fl
# Out:
# '# started 2017-02-07T14:14:05Z\n'

# %%
from itertools import islice
string=['<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context>']
with open("nif_context_en.tql") as myfile:
    head = list(islice(myfile, 10))
    if '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context>' in head :
        print("@")        
print(head)
# Out:
# ['# started 2017-02-07T14:14:05Z\n', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .\n', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .\n', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex> "2294"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .\n', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#sourceUr
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1e00869fb38a> in <module>
#       1
#       2 import pandas as pd
# ----> 3 yourfile = pd.read('nif_context_en.tql',nrows=1000)
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
# Out:
# ['', '']

# %%
file=open('nif_context_en.tql','r')

for i in range(100) :
    fileline=file.readline()
    if '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context>' in fileline :
        print(fileline)
# Out:
# <http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .
#
# <http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .
#
# <http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex> "2294"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .
#
# ...

# %%
file=open('nif_context_en.tql',encoding="utf-8")



for i in range(100) :
    fileline=file.readline()
    print(fileline)
    
data=open('check.txt',encoding="utf-8")
dataline=data.readlines()
print(dataline)
# Out:
# # started 2017-02-07T14:14:05Z
#
# <http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .
#
# <http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .
#
# <http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex> "2294"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .
#
# ...

# %%
file=open('nif_context_en.tql','r')
f=open('Animalia_(book).tql','w')
for i in range(10) :
    fileline=file.readline()
    if '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context>' in fileline :
        f.write(fileline)

# %%
ft=open('Animalia_(book).tql','r')
ft.readlines()
# Out:
# ['<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .\n',
#  '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .\n',
#  '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex> "2294"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .\n',
# ...

# %%
3+2
# Out:
# 5

# %%
previousSubject = None
file=open('nif_context_en.tql',encoding="utf-8")
for i in range(29642397):
    fileline=file.readline()
        s=fileline.find('?')
        thisSubject=fileline[29:s]
        if "/" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("/","")
        if "*" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("*","")
        if "-" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("-","")
        if "_" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("_","")
        if "+" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("+","")
        if "=" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("=","")
        if "?" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("?","")
        if "%" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("%","")    
        if "." in r"%r" % thisSubject:
            thisSubject=thisSubject.replace(".","")    
        if ":" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace(":","")
        if "|" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("|","")
        if ">" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace(">","")
        if "<" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("<","")
        if "\"" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("\"","")
        if "\\" in r"%r" % thisSubject:
            thisSubject=thisSubject.replace("\\","")
        #print(fileline)    
        if previousSubject==thisSubject:
            #append_write='a'
            #f=open(filename,'a')
            #with open(thisSubject+'.tql') as f:
            f.write(fileline);
        else :
            #append_write='w'
            #f=open(thisSubject,append_write)
            f=open("Fulldata/"+thisSubject+".tql",'a',encoding="utf-8")
            #with open(thisSubject+".tql") as f:
            f.write(fileline);

# %%
file=open('instance_types_en.ttl',encoding="utf-8")
for i in range(100):
    fileline=file.readline()
    print(fileline)
# Out:
# # started 2017-03-31T16:36:17Z
#
# <http://dbpedia.org/resource/Anarchism> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#Thing> .
#
# <http://dbpedia.org/resource/Achilles> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#Thing> .
#
# <http://dbpedia.org/resource/Autism> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Disease> .
#
# <http://dbpedia.org/resource/Alabama> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/AdministrativeRegion> .
#
# <http://dbpedia.org/resource/Abraham_Lincoln> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/OfficeHolder> .
#
# <http://dbpedia.org/resource/Abraham_Lincoln__1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/TimePeriod> .
#
# ...

# %%
file=open('nif_context_en.tql',encoding="utf-8")
str='AUX'
for i in range(29642397):
    fileline=file.readline()
    s=fileline.find('?')
    thisSubject=fileline[29:s]
    if thisSubject=='ArchEnemy':
        print(i)
# Out:
# 22825335
# 22825336
# 22825337
# 22825338
# 22825339
# 22825340

# %%
file = open('nif_context_en.tql',encoding='utf-8')
for i in range(20000):
    fileline=file.readline()
    if '<http://dbpedia.org/resource/Anthropology?dbpv=2016-10&nif=context>' in fileline :
        print(fileline)
# Out:
# <http://dbpedia.org/resource/Anthropology?dbpv=2016-10&nif=context> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context> <http://en.wikipedia.org/wiki/Anthropology?oldid=745192902> .
#
# <http://dbpedia.org/resource/Anthropology?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Anthropology?oldid=745192902> .
#
# <http://dbpedia.org/resource/Anthropology?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex> "56286"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Anthropology?oldid=745192902> .
#
# ...

# %%
import nltk

# %%
import pandas

# %%
import numpy

# %%
import matplotlib

# %%
from pyspark import SparkConf

# %%
2+9

# %%
import nltk

# %%
import matplotlib.pyplot as plt

# %%
import nltk
 
text = None
with open('Animalia_(book).tql', 'r') as f:
    text = f.read()
 
sentences = nltk.sent_tokenize(text)
 
print(sentences)
# Out:
# ['<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex> "2294"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610> .', '<http://dbpedia.org/resource/Animalia_(book)?dbpv=2016-10&nif=context> <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#sourceUrl> <http://en.wikipedia.org/wiki/Animalia_
# ...

# %%
import nltk
 
text = None
with open('Animalia_(book).tql', 'r') as f:
    text = f.read()
 
sentences = nltk.sent_tokenize(text)
tokens = [nltk.word_tokenize(sent) for sent in sentences]
     
print(tokens)
# Out:
# [['<', 'http', ':', '//dbpedia.org/resource/Animalia_', '(', 'book', ')', '?', 'dbpv=2016-10', '&', 'nif=context', '>', '<', 'http', ':', '//www.w3.org/1999/02/22-rdf-syntax-ns', '#', 'type', '>', '<', 'http', ':', '//persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core', '#', 'Context', '>', '<', 'http', ':', '//en.wikipedia.org/wiki/Animalia_', '(', 'book', ')', '?', 'oldid=741600610', '>', '.'], ['<', 'http', ':', '//dbpedia.org/resource/Animalia_', '(', 'book', ')', '?', 'dbpv=2016-10', '&', 'nif=context', '>', '<', 'http', ':', '//persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core', '#', 'beginIndex', '>', '``', '0', "''", '^^', '<', 'http', ':', '//www.w3.org/2001/XMLSchema', '#', 'nonNegativeInteger', '>', '<', 'http', ':', '//en.wikipedia.org/wiki/Animalia_', '(', 'book', ')', '?', 'oldid=741600610', '>', '.'], ['<', 'http', ':', '//dbpedia.org/resource/Animalia_', '(', 'book', ')', '?', 'dbpv=2016-10', '&', 'nif=context', '>', '<', 'http', ':', '//persistence.uni-lei
# ...

# %%
import nltk
 
text = None
with open('Animalia_(book).tql', 'r') as f:
    text = f.read()
 
sentences = nltk.sent_tokenize(text)
tokens = [nltk.word_tokenize(sent) for sent in sentences]
tagged = [nltk.pos_tag(sent) for sent in tokens]
 
print(tagged)
# Out:
# [[('<', 'JJ'), ('http', 'NN'), (':', ':'), ('//dbpedia.org/resource/Animalia_', 'NN'), ('(', '('), ('book', 'NN'), (')', ')'), ('?', '.'), ('dbpv=2016-10', 'JJ'), ('&', 'CC'), ('nif=context', 'JJ'), ('>', 'NN'), ('<', 'NNP'), ('http', 'NN'), (':', ':'), ('//www.w3.org/1999/02/22-rdf-syntax-ns', 'JJ'), ('#', '#'), ('type', 'NN'), ('>', 'NN'), ('<', 'NNP'), ('http', 'NN'), (':', ':'), ('//persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core', 'JJ'), ('#', '#'), ('Context', 'NNP'), ('>', 'NNP'), ('<', 'NNP'), ('http', 'NN'), (':', ':'), ('//en.wikipedia.org/wiki/Animalia_', 'NN'), ('(', '('), ('book', 'NN'), (')', ')'), ('?', '.'), ('oldid=741600610', 'JJ'), ('>', 'NN'), ('.', '.')], [('<', 'JJ'), ('http', 'NN'), (':', ':'), ('//dbpedia.org/resource/Animalia_', 'NN'), ('(', '('), ('book', 'NN'), (')', ')'), ('?', '.'), ('dbpv=2016-10', 'JJ'), ('&', 'CC'), ('nif=context', 'JJ'), ('>', 'NN'), ('<', 'NNP'), ('http', 'NN'), (':', ':'), ('//persistence.uni-leipzig.org/nlp2rdf/ontologies/n
# ...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
 
text = None
with open('Animalia_(book).tql', 'r') as f:
    text = f.read()
 
stemmer = PorterStemmer()
tokens = nltk.word_tokenize(text)
 
stems = {token:stemmer.stem(token) for token in tokens}
print(stems)
import nltk
from nltk.stem import WordNetLemmatizer
 
text = None
with open('Animalia_(book).tql', 'r') as f:
    text = f.read()
 
lemmatizer = WordNetLemmatizer()
tokens = nltk.word_tokenize(text)
 
lemmas = {token:lemmatizer.lemmatize(token) for token in tokens}
print(lemmas)
# Out:
# {'<': '<', 'http': 'http', ':': ':', '//dbpedia.org/resource/Animalia_': '//dbpedia.org/resource/animalia_', '(': '(', 'book': 'book', ')': ')', '?': '?', 'dbpv=2016-10': 'dbpv=2016-10', '&': '&', 'nif=context': 'nif=context', '>': '>', '//www.w3.org/1999/02/22-rdf-syntax-ns': '//www.w3.org/1999/02/22-rdf-syntax-n', '#': '#', 'type': 'type', '//persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core': '//persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-cor', 'Context': 'context', '//en.wikipedia.org/wiki/Animalia_': '//en.wikipedia.org/wiki/animalia_', 'oldid=741600610': 'oldid=741600610', '.': '.', 'beginIndex': 'beginindex', '``': '``', '0': '0', "''": "''", '^^': '^^', '//www.w3.org/2001/XMLSchema': '//www.w3.org/2001/xmlschema', 'nonNegativeInteger': 'nonnegativeinteg', 'endIndex': 'endindex', '2294': '2294', 'sourceUrl': 'sourceurl', 'isString': 'isstr', 'Animalia': 'animalia', 'is': 'is', 'an': 'an', 'illustrated': 'illustr', 'children': 'children', "'s": "'s", 'by': 'by', 'G
# ...

# %%
import rdflib
graph = rdflib.Graph()

datae="""hello"""
graph.parse(data=datae)

output = []

for s, p, o in graph:
    if type(o) == rdflib.term.Literal:
        output.append(o.toPython())

print (output)
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\Anaconda3\lib\xml\sax\expatreader.py in feed(self, data, isFinal)
#     216             # except when invoked from close.
# --> 217             self._parser.Parse(data, isFinal)
#     218         except expat.error as e:
#
# ExpatError: syntax error: line 1, column 0
#
# During handling of the above exception, another exception occurred:
#
# SAXParseException                         Traceback (most recent call last)
# <ipython-input-9-05d216564656> in <module>
#       3
#       4 datae="""hello"""
# ----> 5 graph.parse(data=datae)
#       6
#       7 output = []
#
# ~\Anaconda3\lib\site-packages\rdflib\graph.py in parse(self, source, publicID, format, location, file, data, **args)
#    1041         parser = plugin.get(format, Parser)()
#    1042         try:
# -> 1043             parser.parse(source, self, **args)
# ...

# %%
raw_data = """<?xml version="1.0"?>
<rdf:RDF
xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
xmlns:dbp="http://dbpedia.org/ontology/"
xmlns:dbprop="http://dbpedia.org/property/"
xmlns:foaf="http://xmlns.com/foaf/0.1/">
    <rdf:Description rdf:about="http://dbpedia.org/page/Johann_Sebastian_Bach">
      <dbp:birthDate>1685-03-21</dbp:birthDate>
      <dbp:deathDate>1750-07-28</dbp:deathDate>
      <dbp:birthPlace>Eisenach</dbp:birthPlace>
      <dbp:deathPlace>Leipzig</dbp:deathPlace>
      <dbprop:shortDescription>German composer and organist</dbprop:shortDescription>
      <foaf:name>Johann Sebastian Bach</foaf:name>
      <rdf:type rdf:resource="http://dbpedia.org/class/yago/GermanComposers"/>
      <rdf:type rdf:resource="http://xmlns.com/foaf/0.1/Person"/>
    </rdf:Description>
</rdf:RDF>"""
import rdflib
graph = rdflib.Graph()
graph.parse(data=raw_data)

output = []

for s, p, o in graph:
    if type(o) == rdflib.term.Literal:
        output.append(o.toPython())

print(output)
# Out:
# ['Eisenach', 'German composer and organist', '1750-07-28', '1685-03-21', 'Leipzig', 'Johann Sebastian Bach']

# %%
import rdflib

g = rdflib.Graph()
result = g.parse("http://www.w3.org/People/Berners-Lee/card")

# Iterate over triples in store and print them out.
print("--- printing raw triples ---")
for s, p, o in g:
    print((s, p, o))
# Out:
# --- printing raw triples ---
# (rdflib.term.URIRef('https://www.w3.org/People/Berners-Lee/card#i'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'), rdflib.term.Literal('Timothy Berners-Lee'))
# (rdflib.term.BNode('Nde99e73e440243ae9d491a113d813394'), rdflib.term.URIRef('http://www.w3.org/2000/10/swap/pim/contact#street2'), rdflib.term.Literal('MIT CSAIL Room 32-G524'))
# (rdflib.term.BNode('N86c5fd9efb7c4a808476d05418a69eb3'), rdflib.term.URIRef('http://www.w3.org/2006/vcard/ns#locality'), rdflib.term.Literal('Cambridge'))
# (rdflib.term.URIRef('http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('The Next Wave of the Web (Plenary Panel)'))
# (rdflib.term.URIRef('https://www.w3.org/People/Berners-Lee/card#i'), rdflib.term.URIRef('http://www.w3.org/ns/solid/terms#publicTypeIndex'), rdflib.term.URIRef('https://timbl.com/timbl/Public/PublicTypeIndex.ttl'))
# ...

# %%
from rdflib import Graph
f    = open('Animalia_(book).tql',"rb")
text = f.readlines()
g = Graph()
rawdata=open('1980–81_NBA_season.tql')
g.parse('hel.ttl', format='nt')
for s, p, o in g:
    print((s, p, o))
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\rdflib\plugins\parsers\ntriples.py in parse(self, f)
#     139             try:
# --> 140                 self.parseline()
#     141             except ParseError:
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\parsers\ntriples.py in parseline(self)
#     195         object = self.object()
# --> 196         self.eat(r_tail)
#     197
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\parsers\ntriples.py in eat(self, pattern)
#     209             # print repr(self.line), type(self.line)
# --> 210             raise ParseError("Failed to eat %s at %s" % (pattern.pattern, self.line))
#     211         self.line = self.line[m.end():]
#
# ParseError: Failed to eat [ \t]*\.[ \t]*(#.*)? at  <http://en.wikipedia.org/wiki/Animalia_(book)?oldid=741600610>
#
# ...

# %%
import pprint
import rdflib

# %%
from rdflib import Graph

# %%
g=Graph()

# %%
g.triples((s,p,o))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-77388cce6805> in <module>
# ----> 1 g.triples((s,p,o))
#
# NameError: name 's' is not defined

# %%
from rdflib.graph import Graph
g=Graph()
g.parse("Animalia_(book).tql",format="n3")
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\New\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-12-b341a7104988>", line 3, in <module>
#     g.parse("Animalia_(book).tql",format="n3")
#
#   File "C:\Users\New\Anaconda3\lib\site-packages\rdflib\graph.py", line 1043, in parse
#     parser.parse(source, self, **args)
#
#   File "C:\Users\New\Anaconda3\lib\site-packages\rdflib\plugins\parsers\notation3.py", line 1899, in parse
#     TurtleParser.parse(self, source, conj_graph, encoding, turtle=False)
#
#   File "C:\Users\New\Anaconda3\lib\site-packages\rdflib\plugins\parsers\notation3.py", line 1870, in parse
#     p.loadStream(source.getByteStream())
#
#   File "C:\Users\New\Anaconda3\lib\site-packages\rdflib\plugins\parsers\notation3.py", line 434, in loadStream
#     return self.loadBuf(stream.read())    # Not ideal
#
# ...

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
import seaborn as sb

# %%
import numpy as np 
import pandas as pd
import sklearn as sk
